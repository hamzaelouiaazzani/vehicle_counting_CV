# %%
# !pip install --upgrade pip setuptools wheel

# %%
# !pip install -e .

# %%
import torch
if torch.cuda.is_available():
    torch.cuda.get_device_properties(0).name 
torch.cuda.is_available()
# Out:
# False

# %%
import torch
from IPython.display import Image, clear_output  # to display images

clear_output()
print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Setup complete. Using torch 2.2.1+cpu (CPU)

# %%
from counting.run_count import run
from counting.count_ import args

# %%
# !pip install memory_profiler
# %load_ext memory_profiler
# %memit run(args)

# %% [markdown]
# ### To print the documentation about the arguments:

# %%
print(args.__doc__)
# Out:
#     This class contains configuration parameters for the vehicle counting system using the YOLO model and various tracking approaches.
#
#     Attributes:
#         source (str): Filename of the video to perform counting on.
#                       Need to be set.
#         name (str): Name of the folder for the current experiment results.
#                     Need to be set.
#         yolo_model (Path): Path to the YOLO model file.
#                            Default is 'yolov8n.pt'.
#         reid_model (Path): Path to the re-identification model file used if the tracker employs appearance description of objects.
#                            Examples include 'osnet_x0_25_market1501.pt', 'mobilenetv2_x1_4_msmt17.engine', etc.
#         tracking_method (str): Method used for tracking. Options include 'bytetrack', 'botsort', 'strongsort', 'ocsort', 'deepocsort', and 'hybridsort'.
#         imgsz (list): Input size of the frames.
#                       Default is [640].
# ...

# %% [markdown]
# ### To edit some of these arguments:

# %%
args.source
# Out:
# 'kech1.mp4'

# %%
args.source = "kech1.mp4"
args.name = "kech"
args.project = "runs/count"

args.vid_stride = 1
args.verbose = True

args.counting_approach = "detection_only"
args.line_point11 = (0.4, 0.0)
args.line_point12 = (0.4, 1.0)
args.line_vicinity = 0.05
args.line_point21 = (0.6, 0.0)
args.line_point22 = (0.7, 1.0)
args.use_mask = True

# %%
args.source
# Out:
# 'kech1.mp4'

# %% [markdown]
# ### Run the counting over the chosen video with respect to the chosen approach:

# %%
counter_yolo , profilers , results  = run(args)
# Out:
# You are following the detection only in the vicinity of a given line approach.
#
# video 1/1 (1/1336) C:\Users\hamza\OneDrive\Desktop\Jupyter_programs\yolo_tracking_for_counting_\kech1.mp4: 384x640 (no detections), 230.9ms
# video 1/1 (2/1336) C:\Users\hamza\OneDrive\Desktop\Jupyter_programs\yolo_tracking_for_counting_\kech1.mp4: 384x640 1 truck, 175.5ms
# video 1/1 (3/1336) C:\Users\hamza\OneDrive\Desktop\Jupyter_programs\yolo_tracking_for_counting_\kech1.mp4: 384x640 1 truck, 78.8ms
# video 1/1 (4/1336) C:\Users\hamza\OneDrive\Desktop\Jupyter_programs\yolo_tracking_for_counting_\kech1.mp4: 384x640 1 truck, 49.8ms
# video 1/1 (5/1336) C:\Users\hamza\OneDrive\Desktop\Jupyter_programs\yolo_tracking_for_counting_\kech1.mp4: 384x640 (no detections), 47.3ms
# video 1/1 (6/1336) C:\Users\hamza\OneDrive\Desktop\Jupyter_programs\yolo_tracking_for_counting_\kech1.mp4: 384x640 (no detections), 60.1ms
# ...

# %%
counter_yolo.video_attributes , counter_yolo.counting_preprocess , counter_yolo.counting_attributes.keys()
# Out:
# ({'width': 1920, 'height': 1080, 'frame_rate': 30, 'total_frames': 1336},
#  {'use_mask': False},
#  dict_keys(['index_to_label', 'line_vicinity', 'intercept_line1', 'slope1', 'intercept_line2', 'slope2', 'line_point21', 'line_point22', 'counting_approach', 'with_track', 'with_line', 'line_point11', 'line_point12']))

# %%
counter_yolo.counter , counter_yolo.count_per_class
# Out:
# (tensor(37.), tensor([ 0.,  2., 13.,  5.,  0., 17.,  0.,  0.]))

# %%
# counter_yolo.id_to_first_last , len(counter_yolo.id_to_first_last.keys())==counter_yolo.counter

# %%
counter_yolo.ids_frames
